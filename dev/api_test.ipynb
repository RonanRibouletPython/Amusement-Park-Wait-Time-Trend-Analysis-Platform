# %%
import pandas as pd
import requests

# %% [markdown]
# # Check the list of all the parks

# %%
# API endpoint with list of parks
parks_url = "https://queue-times.com/parks.json"

# Make the request
response = requests.get(parks_url)

# Check if the request was successful
if response.status_code == 200:
    print("Successfully retrieved data!")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# Parse the JSON response
parks_data = response.json()

# Print the parks data for debugging
print(parks_data)
# Out:
# Successfully retrieved data!
# [{'id': 11, 'name': 'Cedar Fair Entertainment Company', 'parks': [{'id': 57, 'name': "California's Great America", 'country': 'United States', 'continent': 'North America', 'latitude': '37.397799', 'longitude': '-121.974717', 'timezone': 'America/Los_Angeles'}, {'id': 58, 'name': "Canada's Wonderland", 'country': 'Canada', 'continent': 'North America', 'latitude': '43.843', 'longitude': '-79.539', 'timezone': 'America/Toronto'}, {'id': 59, 'name': 'Carowinds', 'country': 'United States', 'continent': 'North America', 'latitude': '35.1045', 'longitude': '-80.9394', 'timezone': 'America/New_York'}, {'id': 50, 'name': 'Cedar Point', 'country': 'United States', 'continent': 'North America', 'latitude': '41.4822', 'longitude': '-82.6835', 'timezone': 'America/New_York'}, {'id': 69, 'name': 'Dorney Park', 'country': 'United States', 'continent': 'North America', 'latitude': '40.577942', 'longitude': '-75.531528', 'timezone': 'America/New_York'}, {'id': 62, 'name': 'Kings Dominion', 'country': 'United States', 'continent': 'North America', 'latitude': '37.84', 'longitude': '-77.445', 'timezone': 'America/New_York'}, {'id': 60, 'name': 'Kings Island', 'country': 'United States', 'continent': 'North America', 'latitude': '39.3447', 'longitude': '-84.2686', 'timezone': 'America/New_York'}, {'id': 61, 'name': "Knott's Berry Farm", 'country': 'United States', 'continent': 'North America', 'latitude': '33.8442', 'longitude': '-117.9986', 'timezone': 'America/Los_Angeles'}, {'id': 70, 'name': "Michigan's Adventure", 'country': 'United States', 'continent': 'North America', 'latitude': '43.3474', 'longitude': '-86.2789', 'timezone': 'America/New_York'}, {'id': 68, 'name': 'Valleyfair', 'country': 'United States', 'continent': 'North America', 'latitude': '44.798742', 'longitude': '-93.453369', 'timezone': 'America/Chicago'}, {'id': 63, 'name': 'Worlds of Fun', 'country': 'United States', 'continent': 'North America', 'latitude': '39.177333', 'longitude': '-94.489028', 'timezone': 'America/Chicago'}]}, {'id': 21, 'name': 'Chimelong Group', 'parks': [{'id': 331, 'name': 'Chimelong Birds Park', 'country': 'China', 'continent': 'Asia', 'latitude': '23.025', 'longitude': '113.277', 'timezone': 'Asia/Shanghai'}, {'id': 123, 'name': 'Chimelong Ocean Kingdom', 'country': 'China', 'continent': 'Asia', 'latitude': '22.101', 'longitude': '113.534', 'timezone': 'Asia/Shanghai'}, {'id': 130, 'name': 'Chimelong Paradise', 'country': 'China', 'continent': 'Asia', 'latitude': '23.005', 'longitude': '113.327', 'timezone': 'Asia/Shanghai'}, {'id': 330, 'name': 'Chimelong Safari Park', 'country': 'China', 'continent': 'Asia', 'latitude': '23.009', 'longitude': '113.309', 'timezone': 'Asia/Shanghai'}, {'id': 332, 'name': 'Chimelong Spaceship', 'country': 'China', 'continent': 'Asia', 'latitude': '22.097', 'longitude': '113.535', 'timezone': 'Asia/Shanghai'}, {'id': 139, 'name': 'Chimelong Water Park', 'country': 'China', 'continent': 'Asia', 'latitude': '23.004', 'longitude': '113.318', 'timezone': 'Asia/Shanghai'}]}, {'id': 15, 'name': 'Compagnie des Alpes', 'parks': [{'id': 276, 'name': 'Bellewaerde', 'country': 'Belgium', 'continent': 'Europe', 'latitude': '50.846996', 'longitude': '2.947948', 'timezone': 'Europe/Brussels'}, {'id': 322, 'name': 'Familypark', 'country': 'Austria', 'continent': 'Europe', 'latitude': '47.801597', 'longitude': '16.646089', 'timezone': 'Europe/Vienna'}, {'id': 291, 'name': 'Futuroscope', 'country': 'France', 'continent': 'Europe', 'latitude': '46.669167', 'longitude': '0.368889', 'timezone': 'Europe/Paris'}, {'id': 9, 'name': 'Parc Astérix', 'country': 'France', 'continent': 'Europe', 'latitude': '49.1341839', 'longitude': '2.5712301', 'timezone': 'Europe/Paris'}, {'id': 14, 'name': 'Walibi Belgium', 'country': 'Belgium', 'continent': 'Europe', 'latitude': '50.7018603', 'longitude': '4.5940362', 'timezone': 'Europe/Brussels'}, {'id': 53, 'name': 'Walibi Holland', 'country': 'Netherlands', 'continent': 'Europe', 'latitude': '52.44 ...

# %% [markdown]
# # Parse the response data and create a lookup dictionnary

# %%
all_parks = []

# Loop through each company/group in the JSON response
for company in parks_data:
    # Loop through each park within that company's 'parks' list
    for park in company['parks']:
        # Add the park's details to our flat list
        all_parks.append(park)

# Print the number of parks found
print(f"Total number of parks found: {len(all_parks)}")

# Inspect the first park in our new flattened list
if all_parks:
    print("\nSample of a single park's data:")
    print(all_parks[0])

# Create a simple lookup table to map park names to IDs
park_lookup = {park['name']: park['id'] for park in all_parks}
park_lookup
# Out:
# Total number of parks found: 133
#
# Sample of a single park's data:
# {'id': 57, 'name': "California's Great America", 'country': 'United States', 'continent': 'North America', 'latitude': '37.397799', 'longitude': '-121.974717', 'timezone': 'America/Los_Angeles'}
# {"California's Great America": 57,
#  "Canada's Wonderland": 58,
#  'Carowinds': 59,
#  'Cedar Point': 50,
#  'Dorney Park': 69,
#  'Kings Dominion': 62,
#  'Kings Island': 60,
#  "Knott's Berry Farm": 61,
#  "Michigan's Adventure": 70,
#  'Valleyfair': 68,
#  'Worlds of Fun': 63,
#  'Chimelong Birds Park': 331,
#  'Chimelong Ocean Kingdom': 123,
#  'Chimelong Paradise': 130,
#  'Chimelong Safari Park': 330,
#  'Chimelong Spaceship': 332,
#  'Chimelong Water Park': 139,
#  'Bellewaerde': 276,
#  'Familypark': 322,
#  'Futuroscope': 291,
#  'Parc Astérix': 9,
#  'Walibi Belgium': 14,
#  'Walibi Holland': 53,
#  'Walibi Rhône-Alpes': 301,
#  'Europa Park': 51,
#  'Rulantica': 309,
#  'Dollywood': 55,
#  'Silver Dollar City': 10,
#  'Avonturenpark Hellendoorn': 323,
#  'Alton Towers': 1,
#  'Chessington World of Adventures': 3,
#  'Gardaland': 12,
#  'Heide Park': 25,
#  'Legoland Billund': 52,
#  'Legoland California': 279,
#  'Legoland Deutschland': 278,
#  'Legoland Florida': 280,
#  'Legoland Japan': 285,
#  'Legoland Korea': 315,
#  'Legoland New York': 299,
#  'Legoland Windsor': 27,
#  'Peppa Pig Theme Park Florida': 316,
#  'Thorpe Park': 2,
#  'Beto Carrero World': 319,
#  'Blackpool Pleasure Beach': 273,
#  'Cinecittà World': 318,
#  'Djurs Sommerland': 290,
#  'Efteling': 160,
#  'Energylandia': 317,
#  'Fårup Sommerland': 18,
#  'Grona Lund': 166,
#  'Hansa Park': 286,
#  'Hersheypark': 15,
#  'Knoebels': 314,
#  'Le Pal': 303,
#  'Le Parc du Petit Prince': 327,
#  'Liseberg': 11,
#  'Lotte World': 333,
#  'PanoraMagique': 320,
#  'Paultons Park': 49,
#  'Phantasialand': 56,
#  'Toverland': 305,
#  'Vulcania': 304,
#  'Adventureland Resort': 324,
#  'Bobbejaanland': 311,
#  'Kennywood': 312,
#  'Lake Compounce': 313,
#  'Movie Park Germany': 310,
#  'Parque de Atracciones Madrid': 321,
#  'Parque Warner Madrid': 298,
#  'Plopsaland Belgium': 54,
#  'Plopsaland Deutschland': 302,
#  'Ferrari Land': 277,
#  'PortAventura Park': 19,
#  'Caribbean Bay': 329,
#  'Everland': 125,
#  'Adventure Island': 97,
#  'Aquatica Orlando': 94,
#  'Aquatica San Antonio': 306,
#  'Busch Gardens Tampa': 24,
#  'Busch Gardens Williamsburg': 23,
#  'Discovery Cove Orlando': 308,
#  'Seaworld Orlando': 21,
#  'Seaworld San Antonio': 22,
#  'Seaworld San Diego': 20,
#  'Sesame Place': 29,
#  'Water Country USA': 96,
#  'Frontier City': 282,
#  'La Ronde, Montreal': 48,
#  'Six Flags America': 42,
#  'Six Flags Darien Lake': 281,
#  'Six Flags Discovery Kingdom': 33,
#  'Six Flags Fiesta Texas': 39,
#  'Six Flags Great Adventure': 37,
#  'Six Flags Great America': 38,
#  'Six Flags Great Escape': 45,
#  'Six Flags Hurricane Harbor New Jersey': 44,
#  'Six Flags Hurricane Harbor, Arlington': 40,
#  'Six Flags Hurricane Harbor, Concord': 293,
#  'Six Flags Hurricane Harbor, Los Angeles': 41,
#  'Six Flags Hurricane Harbor, Oaxtepec': 292,
#  'Six Flags Hurricane Harbor, Oklahoma City': 294,
#  'Six Flags Hurricane Harbor, Phoenix': 295,
#  'Six Flags Hurricane Harbor, Rockford': 297,
#  'Six Flags Hurricane Harbor, SplashTown': 296,
#  'Six Flags Magic Mountain': 32,
#  'Six Flags Mexico': 47,
#  'Six Flags New England': 43,
#  'Six Flags Over Georgia': 35,
#  'Six Flags Over Texas': 34,
#  'Six Flags St. Louis': 36,
#  'Six Flags White Water, Atlanta': 46,
#  'British Museum': 326,
#  'Natural History Museum': 325,
#  'Epic Universe': 334,
#  'Islands Of Adventure At Universal Orlando': 64,
#  'Universal Studios At Universal Orlando': 65,
#  'Universal Studios Beijing': 328,
#  'Universal Studios Hollywood': 66,
#  'Universal Studios Japan': 284,
#  'Universal Volcano Bay': 67,
#  'Animal Kingdom': 8,
#  'Disney California Adventure': 17,
#  'Disney Hollywood Studios': 7,
#  'Disney Magic Kingdom': 6,
#  'Disneyland': 16,
#  'Disneyland Hong Kong': 31,
#  'Disneyland Park Paris': 4,
#  'Epcot': 5,
#  'Shanghai Disney Resort': 30,
#  'Tokyo Disneyland': 274,
#  'Tokyo DisneySea': 275,
#  'Walt Disney Studios Paris': 28}

# %% [markdown]
# # Check the second endpoint to get info on the queue time

# %%
# Test the second endpoint with the first park
park_url = f"https://queue-times.com/parks/{all_parks[0]['id']}/queue_times.json"

# Make the request
response = requests.get(park_url)

# Check if the request was successful
if response.status_code == 200:
    print("Successfully retrieved data!")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# Parse the JSON response
park_data = response.json()
park_data
# Out:
# Successfully retrieved data!
# {'lands': [{'id': 9,
#    'name': 'Coasters',
#    'rides': [{'id': 5847,
#      'name': 'Demon',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5849,
#      'name': 'Flight Deck',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5853,
#      'name': 'Gold Striker',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5840,
#      'name': 'Grizzly',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5855,
#      'name': 'Patriot',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5835,
#      'name': 'Psycho Mouse',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5852,
#      'name': 'RailBlazer',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'}]},
#   {'id': 11,
#    'name': 'Family',
#    'rides': [{'id': 5838,
#      'name': "Barney Oldfield's Redwood Rally",
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7691,
#      'name': 'Berserker',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7630,
#      'name': 'Carousel Columbia',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7693,
#      'name': 'Celebration Swings',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7631,
#      'name': 'Centrifuge',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 13018,
#      'name': 'Delta Flyer (Skyride)',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 13021,
#      'name': 'Eagles Flight (Skyride)',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7695,
#      'name': 'Flying Eagles',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 10930,
#      'name': 'Liberty Twirler',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5851,
#      'name': 'Mass Effect: New Earth',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 12111,
#      'name': 'Pacific Gliders',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5850,
#      'name': 'Rip Roaring Rapids',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5833,
#      'name': 'Rue Le Dodge',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7642,
#      'name': 'Star Tower',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7633,
#      'name': 'Thunder Raceway',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5842,
#      'name': 'Whitewater Falls',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7720,
#      'name': 'Woodstock Express',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'}]},
#   {'id': 13,
#    'name': 'Kids',
#    'rides': [{'id': 7644,
#      'name': 'Character Carousel',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7635,
#      'name': 'Flying Ace',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7701,
#      'name': 'GR8 SK8',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7639,
#      'name': 'Joe Cools Dodgem School',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7706,
#      'name': 'Kite Eating Tree',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7650,
#      'name': "Lucy's Crabbie Cabbies",
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7656,
#      'name': 'PEANUTS 500',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7647,
#      'name': 'PEANUTS Pirates',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7710,
#      'name': 'Planet Snoopy Construction Zone',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7714,
#      'name': "Sally's Love Buggies",
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7653,
#      'name': "Sally's Swing Set",
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7662,
#      'name': "Snoopy's Space Buggies",
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7658,
#      'name': "Snoopy's Space Race",
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7660,
#      'name': 'The Pumpkin Patch',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'}]},
#   {'id': 10,
#    'name': 'Thrill',
#    'rides': [{'id': 5846,
#      'name': 'Delirium',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5841,
#      'name': 'Drop Tower',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7665,
#      'name': 'The Orbit',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 5843,
#      'name': 'Tiki Twirl',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7668,
#      'name': 'Xtreme Skyflyer',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'}]},
#   {'id': 14,
#    'name': 'Water Park',
#    'rides': [{'id': 13009,
#      'name': 'Barracuda',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7673,
#      'name': 'Breakers Bay',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7670,
#      'name': 'Coastal Cruz',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 10818,
#      'name': 'Feeding Frenzy',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7681,
#      'name': 'Mission Falls',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7678,
#      'name': 'NorCall Wipeout',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7676,
#      'name': 'Otter Trotters',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7683,
#      'name': 'Pups Pier',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 7679,
#      'name': 'Rushin River',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 10816,
#      'name': 'Shark Reef Plunge',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'},
#     {'id': 13057,
#      'name': 'Tide Pool Slides',
#      'is_open': False,
#      'wait_time': 0,
#      'last_updated': '2025-11-16T00:55:22.000Z'}]}],
#  'rides': []}

# %%
# Instead of giving the id we will give the name of the park using the lookup table
park_name = f"Parc Astérix"
park_url = f"https://queue-times.com/parks/{park_lookup[park_name]}/queue_times.json"

# Make the request
response = requests.get(park_url)

# Check if the request was successful
if response.status_code == 200: 
    print("Successfully retrieved data!")   
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# Parse the JSON response
park_data = response.json()
park_data
# Out:
# Successfully retrieved data!
# {'lands': [],
#  'rides': [{'id': 8207,
#    'name': 'Aérodynamix',
#    'is_open': True,
#    'wait_time': 10,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 6457,
#    'name': 'Attention Menhir !',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 14621,
#    'name': 'Catacombes',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 14936,
#    'name': 'Cétautomatix',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 11775,
#    'name': 'Chez Gyrofolix',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5643,
#    'name': 'Discobélix',
#    'is_open': True,
#    'wait_time': 20,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8206,
#    'name': 'Enigmatix',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 13874,
#    'name': 'Epidemaïs Croisières',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8205,
#    'name': 'Etamine',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5651,
#    'name': 'Goudurix',
#    'is_open': True,
#    'wait_time': 10,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 6363,
#    'name': 'Hydrolix',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8216,
#    'name': "L'Aventure Astérix",
#    'is_open': True,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8201,
#    'name': "L'Escadrille des As",
#    'is_open': True,
#    'wait_time': 10,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5659,
#    'name': "L'Hydre de Lerne",
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5657,
#    'name': "L'Oxygénarium",
#    'is_open': True,
#    'wait_time': 25,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 14619,
#    'name': "La Colère d'Anubis",
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5646,
#    'name': 'La Galère',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8189,
#    'name': 'La Petite Tempête',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5648,
#    'name': 'La revanche des pirates - Le Grand Splatch',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5654,
#    'name': "La Rivière d'Elis",
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 13074,
#    'name': 'La tour de Numérobis',
#    'is_open': True,
#    'wait_time': 10,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5650,
#    'name': 'La Trace du Hourra',
#    'is_open': True,
#    'wait_time': 15,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8208,
#    'name': 'Lavomatix',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8184,
#    'name': 'Le Carrousel de César',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 6102,
#    'name': 'Le Cheval de Troie',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 6364,
#    'name': 'Le Petit Train',
#    'is_open': True,
#    'wait_time': 15,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 14595,
#    'name': 'Le tombeau des Dieux',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5660,
#    'name': "Le Vol d'Icare",
#    'is_open': True,
#    'wait_time': 10,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5645,
#    'name': 'Les Chaises Volantes',
#    'is_open': True,
#    'wait_time': 60,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 15307,
#    'name': 'Les Chaudrons infernaux',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 15308,
#    'name': 'Les Enfers de Pompei',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5652,
#    'name': 'Les Espions de César',
#    'is_open': True,
#    'wait_time': 30,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8200,
#    'name': 'Les Petites Chaises Volantes',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8203,
#    'name': 'Les Petits Chars tamponneurs',
#    'is_open': True,
#    'wait_time': 15,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8190,
#    'name': 'Les Petits Drakkars',
#    'is_open': True,
#    'wait_time': 5,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5655,
#    'name': 'Menhir Express',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 15309,
#    'name': 'Mission perdue',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5649,
#    'name': 'OzIris',
#    'is_open': True,
#    'wait_time': 20,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8211,
#    'name': 'Panoramix Play Area',
#    'is_open': True,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5642,
#    'name': 'Pégase Express',
#    'is_open': True,
#    'wait_time': 30,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 8212,
#    'name': 'Petit Chêne Play Area',
#    'is_open': True,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 5647,
#    'name': 'Romus et Rapidus',
#    'is_open': False,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 11774,
#    'name': "Sanglier d'Or playground",
#    'is_open': True,
#    'wait_time': 0,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 6153,
#    'name': 'SOS Tournevis',
#    'is_open': True,
#    'wait_time': 15,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 10760,
#    'name': 'Tonnerre 2 Zeus',
#    'is_open': True,
#    'wait_time': 10,
#    'last_updated': '2025-11-16T16:36:14.000Z'},
#   {'id': 11770,
#    'name': 'Toutatis',
#    'is_open': True,
#    'wait_time': 15,
#    'last_updated': '2025-11-16T16:36:14.000Z'}]}
